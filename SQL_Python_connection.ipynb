# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
from sqlalchemy import text
import getpass # To get the password without showing the input
from urllib.parse import quote_plus
password = getpass.getpass()

# %%
from urllib.parse import quote_plus
bd = "sakila"
connection_string = f"mysql+pymysql://root:{quote_plus(password)}@localhost:3306/{bd}"
engine = create_engine(connection_string)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/sakila)

# %% [markdown]
# #Create Cursor

# %%
def rentals_month(engine, month, year):
    
    query = f"""
    SELECT *
    FROM rental
    WHERE MONTH(rental_date) = {month}
      AND YEAR(rental_date) = {year}
    """
    
    df = pd.read_sql(query, engine)
    
    return df

# %%
df_may = rentals_month(engine, 5, 2005)

# %%
def rental_count_month(df, month, year):
    
    result = df.groupby("customer_id").size().reset_index()
    
    column_name = "rentals_" + str(month) + "_" + str(year)
    
    result.columns = ["customer_id", column_name]
    
    return result

# %%
may_counts = rental_count_month(df_may, 5, 2005)
print(may_counts.head())
# Out:
#    customer_id  rentals_5_2005
# 0            1               2
# 1            2               1
# 2            3               2
# 3            5               3
# 4            6               3
